# %% [markdown]
# # OpenEarhMap Semantinc Segmentation
#
# original implementation found at https://github.com/bao18/open_earth_map/blob/main/Demo.ipynb
#
# ---

# %% [markdown]
# ### Requirements

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !git clone https://github.com/bao18/open_earth_map.git '/content/drive/My Drive/Colab/OEM/' # <= change path where you save code

# %%
# !pip install rasterio

# %%
# import gdown
# import zipfile

# url = "https://drive.google.com/uc?export=download&confirm=pbef&id=1SkziVf0s9gB-VdBWkmQkkpkOy5nbEKdQ"
# output = "/content/drive/My Drive/Colab/OEM/OpenEathMap_Mini.zip" # <= change path where you save data
# gdown.download(url, output, quiet=False)

# %%
# !unzip -q "/content/drive/My Drive/Colab/OEM/OpenEathMap_Mini.zip" -d "/content/drive/My Drive/Colab/OEM/" # <= change path where you save data

# %% [markdown]
# ### Import
# ---

# %%
import os
import time
import warnings
import numpy as np
import torch
import torchvision
from pathlib import Path
import matplotlib.pyplot as plt
import sys
# sys.path.append('/content/drive/My Drive/Colab/OEM') # <= change path where you save code
import open_earth_map as oem

warnings.filterwarnings("ignore")
# os.system("CUDA_VISIBLE_DEVICES=1")
# torch.cuda.set_device(1)  # 使用 GPU 1

# %% [markdown]
# ### Define main parameters

# %%
# Path to the OpenEarthMap directory
OEM_DATA_DIR = "OpenEarthMap_Mini"

# Training and validation file list
TRAIN_LIST = os.path.join(OEM_DATA_DIR, "train.txt")
VAL_LIST = os.path.join(OEM_DATA_DIR, "val.txt")

os.environ['CUDA_VISIBLE_DEVICES'] = '1'

IMG_SIZE = 1024
N_CLASSES = 9
LR = 0.0002
WEIGHT_DECAY = 0.0001
T_MAX = 10
BATCH_SIZE = 4
NUM_EPOCHS = 24
DEVICE = "cuda"
loss_weight = {'jaccard': 0.3, 'dice': 0.3, 'focal': 0.4}
OUTPUT_DIR = "workdir/output/resnext_aug"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ### Prepare training and validation file lists.

# %%
img_paths = [f for f in Path(OEM_DATA_DIR).rglob("*.tif") if "/images/" in str(f)]
train_fns = [str(f) for f in img_paths if f.name in np.loadtxt(TRAIN_LIST, dtype=str)]
val_fns = [str(f) for f in img_paths if f.name in np.loadtxt(VAL_LIST, dtype=str)]

print("Total samples      :", len(img_paths))
print("Training samples   :", len(train_fns))
print("Validation samples :", len(val_fns))
# Out:
# Total samples      : 1068
# Training samples   : 663
# Validation samples : 92

# %% [markdown]
# ### Prepare training and validation augmentations.

# %%
train_augm = torchvision.transforms.Compose(
    [
        # oem.transforms.Mosaic(IMG_SIZE),
        oem.transforms.RandomErasing(),
        oem.transforms.Rotate(),
        oem.transforms.Crop(IMG_SIZE),
        oem.transforms.ColorJitter(),
        oem.transforms.GaussianNoise(),
    ],
)

val_augm = torchvision.transforms.Compose(
    [
        oem.transforms.Resize(IMG_SIZE),
    ],
)

# %% [markdown]
# ### Define training and validation dataloaders

# %%
train_data = oem.dataset.OpenEarthMapDataset(
    train_fns,
    n_classes=N_CLASSES,
    augm=train_augm,
)

val_data = oem.dataset.OpenEarthMapDataset(
    val_fns,
    n_classes=N_CLASSES,
    augm=val_augm,
)

# %%
fig, axs = plt.subplots(2, 5, figsize=(5*1.5, 2*1.5))
fig.subplots_adjust(top=1, bottom=0, left=0, right=1, hspace=0.01, wspace=0.01)

IDX = 1
for i in range(5):
    img, msk, fn = train_data[IDX]

    img = np.moveaxis(img.numpy(), 0, -1)
    msk = oem.utils.make_rgb(np.argmax(msk.numpy(), axis=0))

    axs[0, i].imshow(img)
    axs[0, i].axis("off")
    axs[1, i].imshow(msk)
    axs[1, i].axis("off")
    IDX += 1

plt.show()

# %%
train_data_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=BATCH_SIZE,
    num_workers=10,
    shuffle=True,
    drop_last=True,
)
val_data_loader = torch.utils.data.DataLoader(
    val_data,
    batch_size=BATCH_SIZE,
    num_workers=10,
    shuffle=False,
)

# %% [markdown]
# ### Define the network architecture, optimizer, and criterion

# %%
network = oem.networks.WideResUNet(in_channels=3, n_classes=N_CLASSES)
optimizer = torch.optim.AdamW(network.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_MAX, eta_min=LR/100)
criterion = oem.losses.MultiLoss(loss_weight)

# %%
print(os.environ['CUDA_VISIBLE_DEVICES'])
# Out:
# 1

# %% [markdown]
# ### Train and validate the network

# %%
start = time.time()

max_score = 0
for epoch in range(NUM_EPOCHS):
    print(f"\nEpoch: {epoch + 1}")

    train_logs = oem.runners.train_epoch_with_scheduler(
        model=network,
        optimizer=optimizer,
        scheduler=scheduler,
        criterion=criterion,
        dataloader=train_data_loader,
        device=DEVICE,
        scheduler_type='epoch',
    )

    valid_logs = oem.runners.valid_epoch(
        model=network,
        criterion=criterion,
        dataloader=val_data_loader,
        device=DEVICE,
    )
    epoch_score = valid_logs["Score"]
    if max_score < epoch_score:
        max_score = epoch_score
        oem.utils.save_model(
            model=network,
            epoch=epoch,
            best_score=max_score,
            model_name="model.pth",
            output_dir=OUTPUT_DIR,
        )

print("Elapsed time: {:.3f} min".format((time.time() - start) / 60.0))
# Out:
# Epoch: 1
# Train: 100%|██████████| 165/165 [02:23<00:00,  1.15it/s, Loss=4.14, Score=0.115]
# Valid: 100%|██████████| 23/23 [00:12<00:00,  1.87it/s, Loss=3.78, Score=0.181]
# model saved
#
# Epoch: 2
# Train: 100%|██████████| 165/165 [02:26<00:00,  1.13it/s, Loss=3.62, Score=0.211]
# Valid: 100%|██████████| 23/23 [00:12<00:00,  1.86it/s, Loss=3.53, Score=0.238]
# model saved
#
# Epoch: 3
# Train: 100%|██████████| 165/165 [02:25<00:00,  1.13it/s, Loss=3.35, Score=0.263]
# Valid: 100%|██████████| 23/23 [00:12<00:00,  1.91it/s, Loss=3.2, Score=0.293]
# model saved
#
# Epoch: 4
# Train: 100%|██████████| 165/165 [02:26<00:00,  1.13it/s, Loss=3.18, Score=0.295]
# Valid: 100%|██████████| 23/23 [00:11<00:00,  1.94it/s, Loss=3.17, Score=0.303]
# model saved
#
# Epoch: 5
# Train: 100%|██████████| 165/165 [02:26<00:00,  1.12it/s, Loss=3.07, Score=0.315]
# Valid: 100%|██████████| 23/23 [00:11<00:00,  1.93it/s, Loss=3.1, Score=0.315]
# model saved
#
# Epoch: 6
# Train: 100%|██████████| 165/165 [02:26<00:00,  1.13it/s, Loss=2.99, Score=0.332]
# Valid: 100%|██████████| 23/23 [00:11<00:00,  1.93it/s, Loss=3.02, Score=0.332]
# model saved
#
# Epoch: 7
# Train: 100%|██████████| 165/165 [02:26<00:00,  1.13it/s, Loss=2.88, Score=0.353]
# Valid: 100%|██████████| 23/23 [00:12<00:00,  1.91it/s, Loss=2.92, Score=0.352]
# model saved
#
# Epoch: 8
# Train: 100%|██████████| 165/165 [02:26<00:00,  1.13it/s, Loss=2.85, Score=0.36]
# Valid: 100%|██████████| 23/23 [00:11<00:00,  1.96it/s, Loss=2.85, Score=0.365]
# model saved
#
# Epoch: 9
# Train: 100%|██████████| 165/165 [02:26<00:00,  1.13it/s, Loss=2.76, Score=0.378]
# Valid: 100%|██████████| 23/23 [00:11<00:00,  1.96it/s, Loss=2.8, Score=0.375]
# model saved
#
# Epoch: 10
# Train: 100%|██████████| 165/165 [02:26<00:00,  1.13it/s, Loss=2.72, Score=0.385]
# Valid: 100%|██████████| 23/23 [00:11<00:00,  1.93it/s, Loss=2.8, Score=0.374]
# Epoch: 11
# Train: 100%|██████████| 165/165 [02:28<00:00,  1.11it/s, Loss=2.7, Score=0.388]
# Valid: 100%|██████████| 23/23 [00:12<00:00,  1.89it/s, Loss=2.81, Score=0.374]
# Epoch: 12
# Train: 100%|██████████| 165/165 [02:27<00:00,  1.12it/s, Loss=2.69, Score=0.391]
# Valid: 100%|██████████| 23/23 [00:12<00:00,  1.89it/s, Loss=2.79, Score=0.376]
# model saved
#
# Epoch: 13
# Train: 100%|██████████| 165/165 [02:27<00:00,  1.12it/s, Loss=2.71, Score=0.387]
# Valid: 100%|██████████| 23/23 [00:12<00:00,  1.87it/s, Loss=2.8, Score=0.375]
# Epoch: 14
# Train:   0%|          | 0/165 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 7
#       4 for epoch in range(NUM_EPOCHS):
#       5     print(f"\nEpoch: {epoch + 1}")
# ----> 7     train_logs = oem.runners.train_epoch_with_scheduler(
#       8         model=network,
#       9         optimizer=optimizer,
#      10         scheduler=scheduler,
#      11         criterion=criterion,
#      12         dataloader=train_data_loader,
#      13         device=DEVICE,
#      14         scheduler_type='epoch',
#      15     )
#      17     valid_logs = oem.runners.valid_epoch(
#      18         model=network,
#      19         criterion=criterion,
#      20         dataloader=val_data_loader,
#      21         device=DEVICE,
#      22     )
#      23     epoch_score = valid_logs["Score"]
#
# File ~/project/open_earth_map/open_earth_map/runners.py:124, in train_epoch_with_scheduler(model, optimizer, scheduler, criterion, dataloader, device, scheduler_type)
#     121 model.to(device).train()  # 设置模型为训练模式
#     123 iterator = tqdm(dataloader, desc="Train")  # 初始化进度条
# --> 124 for x, y, *_ in iterator:
#     125     x = x.to(device).float()  # 将输入数据移动到指定设备
#     126     y = y.to(device).float()  # 将标签移动到指定设备
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/site-packages/tqdm/std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
#    1181         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1328, in _MultiProcessingDataLoaderIter._next_data(self)
#    1325     return self._process_data(data)
#    1327 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1328 idx, data = self._get_data()
#    1329 self._tasks_outstanding -= 1
#    1330 if self._dataset_kind == _DatasetKind.Iterable:
#    1331     # Check for _IterableDatasetStopIteration
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1294, in _MultiProcessingDataLoaderIter._get_data(self)
#    1290     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1291     # need to call `.task_done()` because we don't use `.join()`.
#    1292 else:
#    1293     while True:
# -> 1294         success, data = self._try_get_data()
#    1295         if success:
#    1296             return data
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1132, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1119 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1120     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1121     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1129     # Returns a 2-tuple:
#    1130     #   (bool: whether successfully get data, any: data if successful else None)
#    1131     try:
# -> 1132         data = self._data_queue.get(timeout=timeout)
#    1133         return (True, data)
#    1134     except Exception as e:
#    1135         # At timeout and error, we manually check whether any worker has
#    1136         # failed. Note that this is the only mechanism for Windows to detect
#    1137         # worker failures.
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File ~/anaconda3/envs/open-earth-map/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Testing

# %% [markdown]
# ### Prepare testing files

# %%
TEST_LIST = os.path.join(OEM_DATA_DIR, "test.txt")

img_paths = [f for f in Path(OEM_DATA_DIR).rglob("*.tif") if "/images/" in str(f)]
test_fns = [str(f) for f in img_paths if f.name in np.loadtxt(TEST_LIST, dtype=str)]

print("Total samples   :", len(img_paths))
print("Testing samples :", len(test_fns))
# Out:
# Total samples   : 1068
# Testing samples : 313

# %% [markdown]
# ### Define test dataloader

# %%
test_data = oem.dataset.OpenEarthMapDataset(test_fns, n_classes=N_CLASSES, augm=None, testing=True)

# %% [markdown]
# ### Load trained network

# %%
network = oem.networks.WideResUNet(in_channels=3, n_classes=N_CLASSES)
network = oem.utils.load_checkpoint(network, model_name="model.pth", model_dir=OUTPUT_DIR)
# Out:
# Loaded model:model.pth (Epoch=11, Score=0.376)

# %% [markdown]
# ### Visualize predictions

# %%
# visualize predictions
NPLOT = 6
idxs = np.argsort(np.random.rand(len(test_fns)))[:NPLOT]

fig, axs = plt.subplots(2, NPLOT, figsize=(NPLOT*1.5, 2*1.5))
fig.subplots_adjust(top=1, bottom=0, left=0, right=1, hspace=0.01, wspace=0.01)

network.eval().to(DEVICE)
for i, idx in enumerate(idxs):
    img, *_ = test_data[idx]

    with torch.no_grad():
        prd = network(img.unsqueeze(0).to(DEVICE)).squeeze(0).cpu()

    img = np.moveaxis(img.numpy(), 0, -1)
    prd = oem.utils.make_rgb(np.argmax(prd.numpy(), axis=0))

    axs[0, i].imshow(img)
    axs[0, i].axis("off")
    axs[1, i].imshow(prd)
    axs[1, i].axis("off")
plt.show()

# %% [markdown]
# ### Save predictions in png files

# %%
import math
from PIL import Image

PR_DIR = OUTPUT_DIR + "/predictions" # <= change path where you save predictions
os.makedirs(PR_DIR, exist_ok=True)

save_fns = []

network.eval().to(DEVICE)
for test_fn in test_fns:
    img = Image.fromarray(oem.dataset.load_multiband(test_fn))

    w, h = img.size[:2]
    power_h = math.ceil(np.log2(h) / np.log2(2))
    power_w = math.ceil(np.log2(w) / np.log2(2))
    if 2**power_h != h or 2**power_w != w:
      img = img.resize((2**power_w, 2**power_h), resample=Image.BICUBIC)
    img = np.array(img)

    # test time augmentation
    imgs = []
    imgs.append(img.copy())
    imgs.append(img[:, ::-1, :].copy())
    imgs.append(img[::-1, :, :].copy())
    imgs.append(img[::-1, ::-1, :].copy())

    input = torch.cat([torchvision.transforms.functional.to_tensor(x).unsqueeze(0) for x in imgs], dim=0).float().to(DEVICE)

    pred = []
    with torch.no_grad():
      msk = network(input)
      msk = torch.softmax(msk[:, :, ...], dim=1)
      msk = msk.cpu().numpy()
      pred = (msk[0, :, :, :] + msk[1, :, :, ::-1] + msk[2, :, ::-1, :] + msk[3, :, ::-1, ::-1])/4

    pred = Image.fromarray(pred.argmax(axis=0).astype("uint8"))
    y_pr = pred.resize((w, h), resample=Image.NEAREST)

    filename = os.path.basename(test_fn).replace('tif','png')
    save_fn = os.path.join(PR_DIR, filename)
    y_pr.save(save_fn)
    save_fns.append(save_fn)
